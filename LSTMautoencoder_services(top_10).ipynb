# %% [markdown]
# <a href="https://colab.research.google.com/github/NancyBiyahut/intrusion-detection-autoencoder/blob/main/LSTMautoencoder_services(top_10).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tqdm
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder, MinMaxScaler, OneHotEncoder
from mpl_toolkits import mplot3d
from tensorflow.keras.layers import Input, Dense, LSTM, TimeDistributed, RepeatVector
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import Model
import tensorflow.keras.backend as K
from scipy.spatial.distance import euclidean
import random
import seaborn as sns
from sklearn.metrics import confusion_matrix, roc_auc_score, roc_curve, f1_score, precision_score, recall_score, accuracy_score

# %%
df= pd.read_csv('kdd_train1.csv')
df.head()
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0     0.0  0.0  ...                25.0
# 1               0     0.0  0.0  ...                 1.0
# 2               0     0.0  0.0  ...                26.0
# 3               0     0.0  0.0  ...               255.0
# 4               0     0.0  0.0  ...               255.0
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# 2                    0.10                    0.05
# 3                    1.00                    0.00
# 4                    1.00                    0.00
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                         0.17                         0.00
# 1                         0.88                         0.00
# 2                         0.00                         0.00
# 3                         0.03                         0.04
# 4                         0.00                         0.00
#
#    dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                  0.00                      0.00                  0.05
# 1                  0.00                      0.00                  0.00
# 2                  1.00                      1.00                  0.00
# 3                  0.03                      0.01                  0.00
# 4                  0.00                      0.00                  0.00
#
#    dst_host_srv_rerror_rate   labels
# 0                      0.00   normal
# 1                      0.00   normal
# 2                      0.00  neptune
# 3                      0.01   normal
# 4                      0.00   normal
#
# [5 rows x 42 columns]

# %%
service_values = df['service'].unique()
print(service_values)
# Out:
# ['ftp_data' 'other' 'private' 'http' 'remote_job' 'name' 'netbios_ns'
#  'eco_i' 'mtp' 'telnet' 'finger' 'domain_u' 'supdup' 'uucp_path' 'Z39_50'
#  'smtp' 'csnet_ns' 'uucp' 'netbios_dgm' 'urp_i' 'auth' 'domain' 'ftp'
#  'bgp' 'ldap' 'ecr_i' 'gopher' 'vmnet' 'systat' 'http_443' 'efs' 'whois'
#  'imap4' 'iso_tsap' 'echo' 'klogin' 'link' 'sunrpc' 'login' 'kshell'
#  'sql_net' 'time' 'hostnames' 'exec' 'ntp_u' 'discard' 'nntp' 'courier'
#  'ctf' 'ssh' 'daytime' 'shell' 'netstat' 'pop_3' 'nnsp' 'IRC' 'pop_2'
#  'printer' 'tim_i' 'pm_dump' 'red_i' 'netbios_ssn' 'rje' 'X11' 'urh_i'
#  'http_8001' 'aol' 'http_2784']

# %%
column_name = 'service'
# Count the occurrences of each unique value in the column
value_counts = df[column_name].value_counts()
# Calculate the total number of entries in the column
total_entries = df[column_name].count()
# Calculate the occupancy percentage for each unique value
occupancy_percentage = (value_counts / total_entries) * 100
top_values = occupancy_percentage.head(10)
selected_services = [ value for value , percentage in top_values.items()]
print(top_values)
print(selected_services)
# Out:
# service
# http        31.744676
# private     17.566371
# domain_u     7.148960
# smtp         5.781927
# ftp_data     5.477452
# eco_i        3.669240
# other        3.400494
# ecr_i        2.428037
# telnet       1.941808
# finger       1.370140
# Name: count, dtype: float64
# ['http', 'private', 'domain_u', 'smtp', 'ftp_data', 'eco_i', 'other', 'ecr_i', 'telnet', 'finger']

# %%
column_name = 'service'

# Count the occurrences of each unique value in the column
value_counts = df[column_name].value_counts()

# Calculate the total number of entries in the column
total_entries = df[column_name].count()

# Calculate the occupancy percentage for each unique value
occupancy_percentage = (value_counts / total_entries) * 100

# Get the top 10 values by occupancy percentage
top_values = occupancy_percentage.head(10)

selected_services = [value for value, percentage in top_values.items()]

print("Top Values:")
print(top_values)
print("\nSelected Services:")
print(selected_services)

# Calculate the percentage of occurrences where the 'label' field is not 'normal' for each top value
non_normal_percentage = []
for value in selected_services:
    non_normal_count = df[(df[column_name] == value) & (df['labels'] != 'normal')].shape[0]
    total_non_normal_count = df[df['labels'] != 'normal'].shape[0]
    if total_non_normal_count != 0:
        non_normal_percentage.append((non_normal_count / total_non_normal_count) * 100)
    else:
        non_normal_percentage.append(0)

print("\nPercentage of occurrences where 'labels' field is not 'normal' for each top value:")
for i in range(len(selected_services)):
    print(f"{selected_services[i]}: {non_normal_percentage[i]:.2f}%")
# Out:
# Top Values:
# service
# http        31.744676
# private     17.566371
# domain_u     7.148960
# smtp         5.781927
# ftp_data     5.477452
# eco_i        3.669240
# other        3.400494
# ecr_i        2.428037
# telnet       1.941808
# finger       1.370140
# Name: count, dtype: float64
#
# Selected Services:
# ['http', 'private', 'domain_u', 'smtp', 'ftp_data', 'eco_i', 'other', 'ecr_i', 'telnet', 'finger']
#
# Percentage of occurrences where 'labels' field is not 'normal' for each top value:
# http: 3.83%
# private: 35.75%
# domain_u: 0.02%
# smtp: 0.47%
# ftp_data: 3.28%
# eco_i: 7.00%
# other: 2.92%
# ecr_i: 4.85%
# telnet: 2.47%
# finger: 2.00%

# %%
df= pd.read_csv('kdd_train1.csv')
data=df.copy()
categorical_features=[feature for feature in  df.columns if data[feature].dtypes=='O']
categorical_features
# Out:
# ['protocol_type', 'service', 'flag', 'labels']

# %%
#selected_services = ['ftp_data', 'http', 'ssh', 'smtp', 'telnet', 'dns', 'netbios']

# %%
df_http = df[df['service'].isin(selected_services)]

# %%
pd.value_counts(df_http['labels']).plot(kind='bar', figsize=(20, 10))
plt.ylabel('number of instances')
plt.xticks(fontsize=13)
plt.grid()
plt.show()

# %%
pd.value_counts(df['labels']).plot(kind='bar', figsize=(20, 10))
plt.ylabel('number of instances')
plt.xticks(fontsize=13)
plt.grid()
plt.show()

# %%
normal_instances = df_http[df_http['labels']=='normal'].shape[0]
anomalous_instances = df_http[df_http['labels']!='normal'].shape[0]
print(normal_instances)
print(anomalous_instances)
print('percentage of anomalies = {}'.format(100*anomalous_instances/normal_instances))
# Out:
# 32951
# 18888
# percentage of anomalies = 57.32147734514886

# %%
df_http_normal = df_http[df_http['labels']=='normal']

# %%
df_http_normal.shape
# Out:
# (32951, 42)

# %%
# dropping catrgorical columns
df_http_normal.drop(['protocol_type', 'service', 'flag', 'land', 'logged_in', 'is_host_login', 'is_guest_login', 'labels'], axis=1, inplace=True)
# dropping columns with no std deviation
df_http_normal.drop(['wrong_fragment', 'urgent', 'num_failed_logins', 'su_attempted', 'num_file_creations', 'num_outbound_cmds'], axis=1, inplace=True)
# Out:
# <ipython-input-22-c7b3529d7086>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_http_normal.drop(['protocol_type', 'service', 'flag', 'land', 'logged_in', 'is_host_login', 'is_guest_login', 'labels'], axis=1, inplace=True)
# <ipython-input-22-c7b3529d7086>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_http_normal.drop(['wrong_fragment', 'urgent', 'num_failed_logins', 'su_attempted', 'num_file_creations', 'num_outbound_cmds'], axis=1, inplace=True)

# %%
df_http_normal.describe()
# Out:
#            duration     src_bytes     dst_bytes           hot  \
# count  32951.000000  3.295100e+04  3.295100e+04  32951.000000
# mean     156.757215  9.402269e+03  4.068284e+03      0.011441
# std     1248.666214  1.317971e+05  5.998582e+04      0.451156
# min        0.000000  0.000000e+00  0.000000e+00      0.000000
# 25%        0.000000  1.450000e+02  1.050000e+02      0.000000
# 50%        0.000000  2.340000e+02  3.800000e+02      0.000000
# 75%        0.000000  3.230000e+02  2.014000e+03      0.000000
# max    40504.000000  4.357454e+06  5.132416e+06     77.000000
#
#        num_compromised    root_shell      num_root    num_shells  \
# count     32951.000000  32951.000000  32951.000000  32951.000000
# mean          0.622682      0.002033      0.676854      0.000516
# std          43.628748      0.045047     44.111492      0.022708
# min           0.000000      0.000000      0.000000      0.000000
# 25%           0.000000      0.000000      0.000000      0.000000
# 50%           0.000000      0.000000      0.000000      0.000000
# 75%           0.000000      0.000000      0.000000      0.000000
# max        7479.000000      1.000000   7468.000000      1.000000
#
#        num_access_files         count  ...  dst_host_count  \
# count      32951.000000  32951.000000  ...    32951.000000
# mean           0.007830     23.336196  ...      147.446208
# std            0.131754     55.034725  ...      101.892312
# min            0.000000      0.000000  ...        0.000000
# 25%            0.000000      1.000000  ...       40.000000
# 50%            0.000000      4.000000  ...      156.000000
# 75%            0.000000     14.000000  ...      255.000000
# max            8.000000    511.000000  ...      255.000000
#
#        dst_host_srv_count  dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# count        32951.000000            32951.000000            32951.000000
# mean           196.555886                0.834394                0.039021
# std             88.139430                0.304509                0.128270
# min              0.000000                0.000000                0.000000
# 25%            142.000000                0.820000                0.000000
# 50%            255.000000                1.000000                0.000000
# 75%            255.000000                1.000000                0.020000
# max            255.000000                1.000000                1.000000
#
#        dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# count                 32951.000000                 32951.000000
# mean                      0.122675                     0.025410
# std                       0.257282                     0.063937
# min                       0.000000                     0.000000
# 25%                       0.000000                     0.000000
# 50%                       0.010000                     0.010000
# 75%                       0.070000                     0.030000
# max                       1.000000                     1.000000
#
#        dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# count          32951.000000              32951.000000          32951.000000
# mean               0.014107                  0.005987              0.047083
# std                0.093219                  0.056472              0.197671
# min                0.000000                  0.000000              0.000000
# 25%                0.000000                  0.000000              0.000000
# 50%                0.000000                  0.000000              0.000000
# 75%                0.000000                  0.000000              0.000000
# max                1.000000                  1.000000              1.000000
#
#        dst_host_srv_rerror_rate
# count              32951.000000
# mean                   0.043062
# std                    0.188807
# min                    0.000000
# 25%                    0.000000
# 50%                    0.000000
# 75%                    0.000000
# max                    1.000000
#
# [8 rows x 28 columns]

# %%
df_http_normal.boxplot(figsize=(20, 10))
plt.show()

# %%
# scaling the data using standard scaler
scaler = StandardScaler()
df_http_normal = pd.DataFrame(scaler.fit_transform(df_http_normal), columns=df_http_normal.columns)

# %%
# reducing the dimensionality of the data using PCA and covering 80% of the variance in the original data
pca = PCA(n_components=0.80)
pca.fit(df_http_normal)
# Out:
# PCA(n_components=0.8)

# %%
pca_cols = ['PCA_'+ str(i) for i in range(pca.n_components_)]
df_pca = pd.DataFrame(pca.transform(df_http_normal), columns=pca_cols)

# %%
df_pca.head()
# Out:
#       PCA_0     PCA_1     PCA_2     PCA_3     PCA_4     PCA_5     PCA_6  \
# 0 -0.331229  1.796949 -0.382401  0.039630  0.409730 -0.712131 -0.193096
# 1 -0.952233  7.007680 -2.403329  2.465798 -0.601445  2.584479 -0.268212
# 2 -0.000726 -0.432467  0.613165 -2.678531 -0.916914  0.966948 -1.082726
# 3 -0.771532 -1.029887  0.062713  0.210234 -0.069672  0.142587  0.462664
# 4  0.095026 -0.507811  0.067308 -0.747582  1.203908  0.067163 -0.244682
#
#       PCA_7     PCA_8     PCA_9    PCA_10    PCA_11    PCA_12
# 0  0.663530 -0.342352 -0.344348  0.000080  0.030476 -0.126670
# 1 -0.200359  0.337033  0.387428 -0.014262 -0.143981 -0.199285
# 2 -0.493731  0.375964  0.166002  0.039173  0.002873 -0.472791
# 3 -0.045108 -0.499142  0.016533  0.018183  0.061417 -0.446030
# 4 -0.053467  0.243524  0.126709  0.034693 -0.212666  0.873955

# %%
def get_windows(df, window_size=20, stride=10):
  windows_arr = []
  for i in tqdm.tqdm(range(0, len(df)-window_size+1, stride)):
    windows_arr.append(df.iloc[i:i+window_size, :].to_numpy())
  return np.array(windows_arr)

# %%
window_size, stride = 10, 10
windows_arr = get_windows(df_pca, window_size, stride)
# Out:
# 100%|██████████| 3295/3295 [00:00<00:00, 13460.12it/s]

# %%
# shuffling windows for training purpose
indices = np.arange(windows_arr.shape[0])
np.random.shuffle(indices)
windows_shuffled = windows_arr[indices]

# %% [markdown]
# LSTM Autoencoder

# %%
K.clear_session()
# encoder model with stacked LSTM
encoder = Sequential([LSTM(80, return_sequences=True, activation='selu',input_shape=(window_size, 13), dropout=0.2), LSTM(50, activation='selu', return_sequences=True),
                      LSTM(20, activation='selu')], name='encoder')
# decoder model with output dimension same as input dimension
decoder = Sequential([RepeatVector(window_size), LSTM(50, activation='selu', return_sequences=True), LSTM(80, activation='selu',return_sequences=True),
                      TimeDistributed(Dense(13, activation='linear'))], name='decoder')
# creating sequential autoencoder using encoder, decoder as layers
autoencoder = Sequential([encoder, decoder], name='autoencoder')
autoencoder.compile(optimizer='adam', loss = tf.keras.losses.Huber(100.))
autoencoder.summary()
# Out:
# Model: "autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder (Sequential)        (None, 20)                61960
#
#  decoder (Sequential)        (None, 10, 13)            57173
#
# =================================================================
# Total params: 119133 (465.36 KB)
# Trainable params: 119133 (465.36 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
encoder.summary(), decoder.summary()
# Out:
# Model: "encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 10, 80)            30080
#
#  lstm_1 (LSTM)               (None, 10, 50)            26200
#
#  lstm_2 (LSTM)               (None, 20)                5680
#
# =================================================================
# Total params: 61960 (242.03 KB)
# Trainable params: 61960 (242.03 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  repeat_vector (RepeatVecto  (None, 10, 20)            0
#  r)
#
#  lstm_3 (LSTM)               (None, 10, 50)            14200
#
#  lstm_4 (LSTM)               (None, 10, 80)            41920
#
#  time_distributed (TimeDist  (None, 10, 13)            1053
#  ributed)
#
# =================================================================
# Total params: 57173 (223.33 KB)
# Trainable params: 57173 (223.33 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# (None, None)

# %%
check_point = tf.keras.callbacks.ModelCheckpoint('autoencoder.h5', monitor='val_loss', save_best_only=True, mode='min', verbose=1)
train_hist = autoencoder.fit(windows_shuffled, windows_shuffled[:, :, ::-1], batch_size=64, validation_split=0.2, epochs=100, callbacks=[check_point])
# Out:
# Epoch 1/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.8470
# Epoch 1: val_loss improved from inf to 0.83798, saving model to autoencoder.h5
# 42/42 [==============================] - 10s 62ms/step - loss: 0.8450 - val_loss: 0.8380
# Epoch 2/100
#  3/42 [=>............................] - ETA: 1s - loss: 0.7307
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 42/42 [==============================] - ETA: 0s - loss: 0.8160
# Epoch 2: val_loss improved from 0.83798 to 0.81664, saving model to autoencoder.h5
# 42/42 [==============================] - 2s 43ms/step - loss: 0.8160 - val_loss: 0.8166
# Epoch 3/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.7988
# Epoch 3: val_loss improved from 0.81664 to 0.80070, saving model to autoencoder.h5
# 42/42 [==============================] - 2s 42ms/step - loss: 0.7978 - val_loss: 0.8007
# Epoch 4/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.7736
# Epoch 4: val_loss improved from 0.80070 to 0.78436, saving model to autoencoder.h5
# 42/42 [==============================] - 2s 42ms/step - loss: 0.7801 - val_loss: 0.7844
# Epoch 5/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.7692
# Epoch 5: val_loss improved from 0.78436 to 0.77280, saving model to autoencoder.h5
# 42/42 [==============================] - 3s 62ms/step - loss: 0.7689 - val_loss: 0.7728
# Epoch 6/100
# 42/42 [==============================] - ETA: 0s - loss: 0.7555
# Epoch 6: val_loss improved from 0.77280 to 0.75418, saving model to autoencoder.h5
# 42/42 [==============================] - 3s 73ms/step - loss: 0.7555 - val_loss: 0.7542
# Epoch 7/100
# 42/42 [==============================] - ETA: 0s - loss: 0.7401
# Epoch 7: val_loss improved from 0.75418 to 0.73878, saving model to autoencoder.h5
# 42/42 [==============================] - 3s 75ms/step - loss: 0.7401 - val_loss: 0.7388
# Epoch 8/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.7761
# Epoch 8: val_loss improved from 0.73878 to 0.71809, saving model to autoencoder.h5
# 42/42 [==============================] - 3s 82ms/step - loss: 0.7764 - val_loss: 0.7181
# Epoch 9/100
# 42/42 [==============================] - ETA: 0s - loss: 0.7163
# Epoch 9: val_loss improved from 0.71809 to 0.69491, saving model to autoencoder.h5
# 42/42 [==============================] - 4s 99ms/step - loss: 0.7163 - val_loss: 0.6949
# Epoch 10/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.7060
# Epoch 10: val_loss did not improve from 0.69491
# 42/42 [==============================] - 3s 81ms/step - loss: 0.7053 - val_loss: 0.7007
# Epoch 11/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.6872
# Epoch 11: val_loss improved from 0.69491 to 0.67162, saving model to autoencoder.h5
# 42/42 [==============================] - 3s 79ms/step - loss: 0.6862 - val_loss: 0.6716
# Epoch 12/100
# 42/42 [==============================] - ETA: 0s - loss: 0.6776
# Epoch 12: val_loss did not improve from 0.67162
# 42/42 [==============================] - 4s 94ms/step - loss: 0.6776 - val_loss: 0.6919
# Epoch 13/100
# 42/42 [==============================] - ETA: 0s - loss: 0.6821
# Epoch 13: val_loss improved from 0.67162 to 0.65775, saving model to autoencoder.h5
# 42/42 [==============================] - 5s 115ms/step - loss: 0.6821 - val_loss: 0.6577
# Epoch 14/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.6616
# Epoch 14: val_loss improved from 0.65775 to 0.64624, saving model to autoencoder.h5
# 42/42 [==============================] - 4s 99ms/step - loss: 0.6614 - val_loss: 0.6462
# Epoch 15/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.6605
# Epoch 15: val_loss improved from 0.64624 to 0.64212, saving model to autoencoder.h5
# 42/42 [==============================] - 2s 42ms/step - loss: 0.6598 - val_loss: 0.6421
# Epoch 16/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.6095
# Epoch 16: val_loss did not improve from 0.64212
# 42/42 [==============================] - 2s 41ms/step - loss: 0.6488 - val_loss: 0.6493
# Epoch 17/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.6517
# Epoch 17: val_loss improved from 0.64212 to 0.61527, saving model to autoencoder.h5
# 42/42 [==============================] - 3s 67ms/step - loss: 0.6507 - val_loss: 0.6153
# Epoch 18/100
# 42/42 [==============================] - ETA: 0s - loss: 0.6217
# Epoch 18: val_loss did not improve from 0.61527
# 42/42 [==============================] - 2s 45ms/step - loss: 0.6217 - val_loss: 0.6334
# Epoch 19/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.6386
# Epoch 19: val_loss improved from 0.61527 to 0.60467, saving model to autoencoder.h5
# 42/42 [==============================] - 2s 43ms/step - loss: 0.6383 - val_loss: 0.6047
# Epoch 20/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.6198
# Epoch 20: val_loss improved from 0.60467 to 0.59953, saving model to autoencoder.h5
# 42/42 [==============================] - 2s 43ms/step - loss: 0.6188 - val_loss: 0.5995
# Epoch 21/100
# 42/42 [==============================] - ETA: 0s - loss: 0.6120
# Epoch 21: val_loss improved from 0.59953 to 0.58630, saving model to autoencoder.h5
# 42/42 [==============================] - 2s 43ms/step - loss: 0.6120 - val_loss: 0.5863
# Epoch 22/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.6188
# Epoch 22: val_loss did not improve from 0.58630
# 42/42 [==============================] - 2s 47ms/step - loss: 0.6178 - val_loss: 0.5988
# Epoch 23/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.6007
# Epoch 23: val_loss improved from 0.58630 to 0.58254, saving model to autoencoder.h5
# 42/42 [==============================] - 2s 55ms/step - loss: 0.6001 - val_loss: 0.5825
# Epoch 24/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.5932
# Epoch 24: val_loss improved from 0.58254 to 0.57491, saving model to autoencoder.h5
# 42/42 [==============================] - 2s 59ms/step - loss: 0.5926 - val_loss: 0.5749
# Epoch 25/100
# 42/42 [==============================] - ETA: 0s - loss: 0.5937
# Epoch 25: val_loss improved from 0.57491 to 0.57443, saving model to autoencoder.h5
# 42/42 [==============================] - 2s 43ms/step - loss: 0.5937 - val_loss: 0.5744
# Epoch 26/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.5920
# Epoch 26: val_loss improved from 0.57443 to 0.56798, saving model to autoencoder.h5
# 42/42 [==============================] - 2s 43ms/step - loss: 0.5915 - val_loss: 0.5680
# Epoch 27/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.6024
# Epoch 27: val_loss did not improve from 0.56798
# 42/42 [==============================] - 2s 42ms/step - loss: 0.6020 - val_loss: 0.5812
# Epoch 28/100
# 42/42 [==============================] - ETA: 0s - loss: 0.5957
# Epoch 28: val_loss did not improve from 0.56798
# 42/42 [==============================] - 2s 42ms/step - loss: 0.5957 - val_loss: 0.5705
# Epoch 29/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.5875
# Epoch 29: val_loss improved from 0.56798 to 0.54867, saving model to autoencoder.h5
# 42/42 [==============================] - 2s 42ms/step - loss: 0.5862 - val_loss: 0.5487
# Epoch 30/100
# 42/42 [==============================] - ETA: 0s - loss: 0.6599
# Epoch 30: val_loss did not improve from 0.54867
# 42/42 [==============================] - 3s 72ms/step - loss: 0.6599 - val_loss: 0.5656
# Epoch 31/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.5956
# Epoch 31: val_loss did not improve from 0.54867
# 42/42 [==============================] - 2s 43ms/step - loss: 0.5946 - val_loss: 0.5616
# Epoch 32/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.5779
# Epoch 32: val_loss improved from 0.54867 to 0.53154, saving model to autoencoder.h5
# 42/42 [==============================] - 2s 43ms/step - loss: 0.5774 - val_loss: 0.5315
# Epoch 33/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.5808
# Epoch 33: val_loss did not improve from 0.53154
# 42/42 [==============================] - 2s 42ms/step - loss: 0.5803 - val_loss: 0.5509
# Epoch 34/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.5668
# Epoch 34: val_loss did not improve from 0.53154
# 42/42 [==============================] - 2s 42ms/step - loss: 0.5662 - val_loss: 0.5372
# Epoch 35/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.5563
# Epoch 35: val_loss improved from 0.53154 to 0.51098, saving model to autoencoder.h5
# 42/42 [==============================] - 2s 44ms/step - loss: 0.5559 - val_loss: 0.5110
# Epoch 36/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.5542
# Epoch 36: val_loss did not improve from 0.51098
# 42/42 [==============================] - 3s 62ms/step - loss: 0.5527 - val_loss: 0.5111
# Epoch 37/100
# 42/42 [==============================] - ETA: 0s - loss: 0.5372
# Epoch 37: val_loss improved from 0.51098 to 0.49994, saving model to autoencoder.h5
# 42/42 [==============================] - 2s 50ms/step - loss: 0.5372 - val_loss: 0.4999
# Epoch 38/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.5241
# Epoch 38: val_loss did not improve from 0.49994
# 42/42 [==============================] - 2s 41ms/step - loss: 0.5231 - val_loss: 0.5037
# Epoch 39/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.5442
# Epoch 39: val_loss did not improve from 0.49994
# 42/42 [==============================] - 2s 41ms/step - loss: 0.5456 - val_loss: 0.5383
# Epoch 40/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.5712
# Epoch 40: val_loss did not improve from 0.49994
# 42/42 [==============================] - 2s 46ms/step - loss: 0.5703 - val_loss: 0.5100
# Epoch 41/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.5544
# Epoch 41: val_loss did not improve from 0.49994
# 42/42 [==============================] - 2s 41ms/step - loss: 0.5545 - val_loss: 0.5440
# Epoch 42/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.5480
# Epoch 42: val_loss improved from 0.49994 to 0.49800, saving model to autoencoder.h5
# 42/42 [==============================] - 2s 47ms/step - loss: 0.5474 - val_loss: 0.4980
# Epoch 43/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.6095
# Epoch 43: val_loss did not improve from 0.49800
# 42/42 [==============================] - 3s 65ms/step - loss: 0.6084 - val_loss: 0.5894
# Epoch 44/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.5990
# Epoch 44: val_loss did not improve from 0.49800
# 42/42 [==============================] - 2s 42ms/step - loss: 0.5988 - val_loss: 0.5285
# Epoch 45/100
# 42/42 [==============================] - ETA: 0s - loss: 0.5682
# Epoch 45: val_loss did not improve from 0.49800
# 42/42 [==============================] - 2s 42ms/step - loss: 0.5682 - val_loss: 0.5260
# Epoch 46/100
# 42/42 [==============================] - ETA: 0s - loss: 0.5501
# Epoch 46: val_loss improved from 0.49800 to 0.49796, saving model to autoencoder.h5
# 42/42 [==============================] - 2s 42ms/step - loss: 0.5501 - val_loss: 0.4980
# Epoch 47/100
# 42/42 [==============================] - ETA: 0s - loss: 0.5395
# Epoch 47: val_loss did not improve from 0.49796
# 42/42 [==============================] - 2s 42ms/step - loss: 0.5395 - val_loss: 0.5021
# Epoch 48/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.5422
# Epoch 48: val_loss did not improve from 0.49796
# 42/42 [==============================] - 2s 41ms/step - loss: 0.5418 - val_loss: 0.5047
# Epoch 49/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.5327
# Epoch 49: val_loss improved from 0.49796 to 0.47593, saving model to autoencoder.h5
# 42/42 [==============================] - 3s 66ms/step - loss: 0.5317 - val_loss: 0.4759
# Epoch 50/100
# 42/42 [==============================] - ETA: 0s - loss: 0.5385
# Epoch 50: val_loss did not improve from 0.47593
# 42/42 [==============================] - 2s 48ms/step - loss: 0.5385 - val_loss: 0.4990
# Epoch 51/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.5179
# Epoch 51: val_loss improved from 0.47593 to 0.46891, saving model to autoencoder.h5
# 42/42 [==============================] - 2s 43ms/step - loss: 0.5169 - val_loss: 0.4689
# Epoch 52/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.5149
# Epoch 52: val_loss did not improve from 0.46891
# 42/42 [==============================] - 2s 42ms/step - loss: 0.5141 - val_loss: 0.5014
# Epoch 53/100
# 42/42 [==============================] - ETA: 0s - loss: 0.5152
# Epoch 53: val_loss did not improve from 0.46891
# 42/42 [==============================] - 2s 41ms/step - loss: 0.5152 - val_loss: 0.4721
# Epoch 54/100
# 42/42 [==============================] - ETA: 0s - loss: 0.5145
# Epoch 54: val_loss did not improve from 0.46891
# 42/42 [==============================] - 2s 42ms/step - loss: 0.5145 - val_loss: 0.4713
# Epoch 55/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.5085
# Epoch 55: val_loss did not improve from 0.46891
# 42/42 [==============================] - 2s 51ms/step - loss: 0.5079 - val_loss: 0.4697
# Epoch 56/100
# 42/42 [==============================] - ETA: 0s - loss: 0.4940
# Epoch 56: val_loss did not improve from 0.46891
# 42/42 [==============================] - 3s 63ms/step - loss: 0.4940 - val_loss: 0.4741
# Epoch 57/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.5141
# Epoch 57: val_loss did not improve from 0.46891
# 42/42 [==============================] - 2s 46ms/step - loss: 0.5136 - val_loss: 0.4771
# Epoch 58/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.4957
# Epoch 58: val_loss did not improve from 0.46891
# 42/42 [==============================] - 2s 43ms/step - loss: 0.4951 - val_loss: 0.4834
# Epoch 59/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.4987
# Epoch 59: val_loss did not improve from 0.46891
# 42/42 [==============================] - 2s 43ms/step - loss: 0.4975 - val_loss: 0.5091
# Epoch 60/100
# 42/42 [==============================] - ETA: 0s - loss: 0.5136
# Epoch 60: val_loss did not improve from 0.46891
# 42/42 [==============================] - 2s 47ms/step - loss: 0.5136 - val_loss: 0.4698
# Epoch 61/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.5137
# Epoch 61: val_loss did not improve from 0.46891
# 42/42 [==============================] - 2s 47ms/step - loss: 0.5129 - val_loss: 0.4878
# Epoch 62/100
# 42/42 [==============================] - ETA: 0s - loss: 0.5063
# Epoch 62: val_loss did not improve from 0.46891
# 42/42 [==============================] - 3s 68ms/step - loss: 0.5063 - val_loss: 0.4871
# Epoch 63/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.4945
# Epoch 63: val_loss improved from 0.46891 to 0.46866, saving model to autoencoder.h5
# 42/42 [==============================] - 3s 60ms/step - loss: 0.4939 - val_loss: 0.4687
# Epoch 64/100
# 42/42 [==============================] - ETA: 0s - loss: 0.4786
# Epoch 64: val_loss did not improve from 0.46866
# 42/42 [==============================] - 2s 50ms/step - loss: 0.4786 - val_loss: 0.4713
# Epoch 65/100
# 42/42 [==============================] - ETA: 0s - loss: 0.4655
# Epoch 65: val_loss improved from 0.46866 to 0.46721, saving model to autoencoder.h5
# 42/42 [==============================] - 2s 44ms/step - loss: 0.4655 - val_loss: 0.4672
# Epoch 66/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.4793
# Epoch 66: val_loss improved from 0.46721 to 0.45747, saving model to autoencoder.h5
# 42/42 [==============================] - 2s 45ms/step - loss: 0.4786 - val_loss: 0.4575
# Epoch 67/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.4566
# Epoch 67: val_loss improved from 0.45747 to 0.45504, saving model to autoencoder.h5
# 42/42 [==============================] - 2s 59ms/step - loss: 0.4560 - val_loss: 0.4550
# Epoch 68/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.4673
# Epoch 68: val_loss did not improve from 0.45504
# 42/42 [==============================] - 3s 63ms/step - loss: 0.4684 - val_loss: 0.4774
# Epoch 69/100
# 42/42 [==============================] - ETA: 0s - loss: 0.4631
# Epoch 69: val_loss improved from 0.45504 to 0.44763, saving model to autoencoder.h5
# 42/42 [==============================] - 2s 47ms/step - loss: 0.4631 - val_loss: 0.4476
# Epoch 70/100
# 42/42 [==============================] - ETA: 0s - loss: 0.4521
# Epoch 70: val_loss did not improve from 0.44763
# 42/42 [==============================] - 2s 43ms/step - loss: 0.4521 - val_loss: 0.4582
# Epoch 71/100
# 42/42 [==============================] - ETA: 0s - loss: 0.4915
# Epoch 71: val_loss did not improve from 0.44763
# 42/42 [==============================] - 2s 44ms/step - loss: 0.4915 - val_loss: 0.4743
# Epoch 72/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.4807
# Epoch 72: val_loss improved from 0.44763 to 0.43925, saving model to autoencoder.h5
# 42/42 [==============================] - 2s 45ms/step - loss: 0.4801 - val_loss: 0.4393
# Epoch 73/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.4810
# Epoch 73: val_loss did not improve from 0.43925
# 42/42 [==============================] - 3s 61ms/step - loss: 0.4800 - val_loss: 0.4829
# Epoch 74/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.4869
# Epoch 74: val_loss did not improve from 0.43925
# 42/42 [==============================] - 3s 62ms/step - loss: 0.4864 - val_loss: 0.4852
# Epoch 75/100
# 42/42 [==============================] - ETA: 0s - loss: 0.4751
# Epoch 75: val_loss did not improve from 0.43925
# 42/42 [==============================] - 2s 44ms/step - loss: 0.4751 - val_loss: 0.4565
# Epoch 76/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.4463
# Epoch 76: val_loss did not improve from 0.43925
# 42/42 [==============================] - 2s 43ms/step - loss: 0.4459 - val_loss: 0.4521
# Epoch 77/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.4773
# Epoch 77: val_loss did not improve from 0.43925
# 42/42 [==============================] - 2s 43ms/step - loss: 0.4764 - val_loss: 0.4579
# Epoch 78/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.4907
# Epoch 78: val_loss did not improve from 0.43925
# 42/42 [==============================] - 2s 43ms/step - loss: 0.4896 - val_loss: 0.4653
# Epoch 79/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.4714
# Epoch 79: val_loss did not improve from 0.43925
# 42/42 [==============================] - 2s 50ms/step - loss: 0.4705 - val_loss: 0.4513
# Epoch 80/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.4742
# Epoch 80: val_loss did not improve from 0.43925
# 42/42 [==============================] - 3s 66ms/step - loss: 0.4736 - val_loss: 0.4713
# Epoch 81/100
# 42/42 [==============================] - ETA: 0s - loss: 0.4565
# Epoch 81: val_loss did not improve from 0.43925
# 42/42 [==============================] - 2s 44ms/step - loss: 0.4565 - val_loss: 0.4410
# Epoch 82/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.4672
# Epoch 82: val_loss did not improve from 0.43925
# 42/42 [==============================] - 2s 47ms/step - loss: 0.4667 - val_loss: 0.4532
# Epoch 83/100
# 42/42 [==============================] - ETA: 0s - loss: 0.4401
# Epoch 83: val_loss did not improve from 0.43925
# 42/42 [==============================] - 2s 44ms/step - loss: 0.4401 - val_loss: 0.4875
# Epoch 84/100
# 42/42 [==============================] - ETA: 0s - loss: 0.4613
# Epoch 84: val_loss did not improve from 0.43925
# 42/42 [==============================] - 2s 43ms/step - loss: 0.4613 - val_loss: 0.4516
# Epoch 85/100
# 42/42 [==============================] - ETA: 0s - loss: 0.4608
# Epoch 85: val_loss did not improve from 0.43925
# 42/42 [==============================] - 2s 43ms/step - loss: 0.4608 - val_loss: 0.4624
# Epoch 86/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.4372
# Epoch 86: val_loss did not improve from 0.43925
# 42/42 [==============================] - 3s 73ms/step - loss: 0.4374 - val_loss: 0.4417
# Epoch 87/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.4264
# Epoch 87: val_loss did not improve from 0.43925
# 42/42 [==============================] - 2s 42ms/step - loss: 0.4258 - val_loss: 0.4524
# Epoch 88/100
# 42/42 [==============================] - ETA: 0s - loss: 0.4243
# Epoch 88: val_loss did not improve from 0.43925
# 42/42 [==============================] - 2s 43ms/step - loss: 0.4243 - val_loss: 0.4735
# Epoch 89/100
# 42/42 [==============================] - ETA: 0s - loss: 0.4163
# Epoch 89: val_loss improved from 0.43925 to 0.43399, saving model to autoencoder.h5
# 42/42 [==============================] - 2s 44ms/step - loss: 0.4163 - val_loss: 0.4340
# Epoch 90/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.4226
# Epoch 90: val_loss did not improve from 0.43399
# 42/42 [==============================] - 2s 43ms/step - loss: 0.4220 - val_loss: 0.4669
# Epoch 91/100
# 42/42 [==============================] - ETA: 0s - loss: 0.4205
# Epoch 91: val_loss did not improve from 0.43399
# 42/42 [==============================] - 2s 43ms/step - loss: 0.4205 - val_loss: 0.4588
# Epoch 92/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.4148
# Epoch 92: val_loss did not improve from 0.43399
# 42/42 [==============================] - 3s 65ms/step - loss: 0.4141 - val_loss: 0.4399
# Epoch 93/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.4194
# Epoch 93: val_loss did not improve from 0.43399
# 42/42 [==============================] - 2s 54ms/step - loss: 0.4188 - val_loss: 0.4572
# Epoch 94/100
# 42/42 [==============================] - ETA: 0s - loss: 0.4260
# Epoch 94: val_loss did not improve from 0.43399
# 42/42 [==============================] - 2s 44ms/step - loss: 0.4260 - val_loss: 0.4370
# Epoch 95/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.4286
# Epoch 95: val_loss did not improve from 0.43399
# 42/42 [==============================] - 2s 43ms/step - loss: 0.4278 - val_loss: 0.4432
# Epoch 96/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.4162
# Epoch 96: val_loss did not improve from 0.43399
# 42/42 [==============================] - 2s 43ms/step - loss: 0.4159 - val_loss: 0.4452
# Epoch 97/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.4536
# Epoch 97: val_loss did not improve from 0.43399
# 42/42 [==============================] - 2s 42ms/step - loss: 0.4532 - val_loss: 0.4485
# Epoch 98/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.4331
# Epoch 98: val_loss did not improve from 0.43399
# 42/42 [==============================] - 2s 54ms/step - loss: 0.4330 - val_loss: 0.4465
# Epoch 99/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.4727
# Epoch 99: val_loss did not improve from 0.43399
# 42/42 [==============================] - 3s 63ms/step - loss: 0.4725 - val_loss: 0.4554
# Epoch 100/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.5279
# Epoch 100: val_loss did not improve from 0.43399
# 42/42 [==============================] - 2s 44ms/step - loss: 0.5266 - val_loss: 0.4427

# %%
# restoring the best model
autoencoder_loaded = tf.keras.models.load_model('autoencoder.h5')

# %% [markdown]
# Testing

# %%
# loading the test dataframe
test_df = pd.read_csv('kdd_test1.csv')
test_df.head()
# Out:
#    duration protocol_type   service  flag  src_bytes  dst_bytes  land  \
# 0         5           tcp      smtp    SF       2429        475     0
# 1         0           udp  domain_u    SF         45        134     0
# 2         0           udp  domain_u    SF         45         80     0
# 3      1979           udp     other    SF        145        105     0
# 4     14462           tcp     other  RSTR          1          0     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  57
# 1               0       0    0  ...                 155
# 2               0       0    0  ...                 255
# 3               0       0    0  ...                   2
# 4               0       0    0  ...                   2
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.11                    0.02
# 1                    0.80                    0.02
# 2                    1.00                    0.00
# 3                    0.01                    0.84
# 4                    0.01                    0.68
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                         0.01                         0.04
# 1                         0.01                         0.00
# 2                         0.01                         0.00
# 3                         1.00                         0.00
# 4                         1.00                         0.00
#
#    dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                   0.0                       0.0                  0.87
# 1                   0.0                       0.0                  0.00
# 2                   0.0                       0.0                  0.00
# 3                   0.0                       0.0                  0.00
# 4                   0.0                       0.0                  1.00
#
#    dst_host_srv_rerror_rate     labels
# 0                       0.0     normal
# 1                       0.0     normal
# 2                       0.0     normal
# 3                       0.0     normal
# 4                       1.0  portsweep
#
# [5 rows x 42 columns]

# %%
# slicing only the rows belonging to http service
test_df_http =   test_df[test_df['service'].isin(selected_services)]

# %%
# binary indicator to represent anomalies
status = pd.Series([0 if i=='normal' else 1 for i in test_df_http['labels']])
test_labels = [1 if np.sum(status[i:i+window_size])>0 else 0 for i in range(0, len(status)-window_size+1, stride)]

# %%
# dropping catrgorical columns
test_df_http.drop(['protocol_type', 'service', 'flag', 'land', 'logged_in', 'is_host_login', 'is_guest_login', 'labels'], axis=1, inplace=True)
# dropping columns with no std deviation
test_df_http.drop(['wrong_fragment', 'urgent', 'num_failed_logins', 'su_attempted', 'num_file_creations', 'num_outbound_cmds'], axis=1, inplace=True)
# Out:
# <ipython-input-39-e48dd4a85e10>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df_http.drop(['protocol_type', 'service', 'flag', 'land', 'logged_in', 'is_host_login', 'is_guest_login', 'labels'], axis=1, inplace=True)
# <ipython-input-39-e48dd4a85e10>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df_http.drop(['wrong_fragment', 'urgent', 'num_failed_logins', 'su_attempted', 'num_file_creations', 'num_outbound_cmds'], axis=1, inplace=True)

# %%
test_df_http = pd.DataFrame(scaler.transform(test_df_http), columns=test_df_http.columns)

# %%
test_df_http_pca = pd.DataFrame(pca.transform(test_df_http), columns=pca_cols)
test_df_http_pca.head()
# Out:
#       PCA_0     PCA_1     PCA_2     PCA_3     PCA_4     PCA_5     PCA_6  \
# 0  1.603644  1.508697 -0.358343  0.345409 -0.073458 -0.575769  0.251328
# 1 -1.535004 -1.404372 -0.102175  2.657356 -3.123279 -0.560040 -0.748784
# 2 -1.187074 -1.601422  0.053693  1.357838 -1.543495 -0.084660 -0.015013
# 3 -0.668534  5.945036 -1.105800  1.600114 -0.158312 -2.394428 -2.588625
# 4  8.587832  7.702723  0.001899  4.589467 -2.835436 -4.388202 -1.511997
#
#       PCA_7     PCA_8     PCA_9    PCA_10    PCA_11    PCA_12
# 0  0.703560 -0.677508 -0.544458 -0.014814  0.087931 -0.334045
# 1  0.321554  0.514810 -0.323709 -0.065617 -0.182144  1.184342
# 2  0.003656 -0.033927 -0.056164 -0.017403  0.000306  0.025626
# 3  0.228686 -1.693632  1.065898  0.290636 -0.422506 -1.259855
# 4 -2.111575 -5.012755  2.659821  0.543979 -0.081826 -4.180082

# %%
test_windows = get_windows(test_df_http_pca, window_size=10, stride=10)
# Out:
# 100%|██████████| 1835/1835 [00:00<00:00, 15953.05it/s]

# %%
test_windows_pred = autoencoder_loaded.predict(test_windows)
# Out:
# 58/58 [==============================] - 1s 10ms/step

# %%
# calculating reconstruction error for each sample
# implemented in tensorflow for faster execution when gpu is available

def get_recon_erros(true_windows, pred_windows):
  recon_errors = []

  def cond(y_true, y_pred, i, iters):
    return tf.less(i, iters)

  def body(y_true, y_pred, i, iters):
    tensor_for_error = tf.math.subtract(tf.slice(y_true, [i, 0, 0], [1, -1, -1]), tf.slice(y_pred, [i, 0, 0], [1, -1, -1]))
    tensor_for_error = tf.reshape(tensor_for_error, [window_size, pca.n_components_])
    recon_error = tf.math.reduce_mean(tf.norm(tensor_for_error, ord='euclidean', axis=1))
    # this is the list initialized above
    recon_errors.append(recon_error.numpy())
    return [y_true, y_pred, tf.add(i, 1), iters]

  iters = tf.constant(len(true_windows))

  result = tf.while_loop(cond, body, [tf.constant(true_windows.astype(np.float32)), tf.constant(pred_windows.astype(np.float32)), 0, iters])
  return recon_errors

# %%
recon_errors = get_recon_erros(test_windows, test_windows_pred)
recon_errors = np.array(recon_errors).reshape(-1, 1)

# %%
# scaling the reconstruction errors set to [0, 1] scale
mm_scaler = MinMaxScaler()
anomaly_scores = mm_scaler.fit_transform(recon_errors).flatten()

# %%
plt.figure(figsize=(20, 10))
plt.plot(test_labels, c='blue', label='original')
plt.plot(anomaly_scores, c='red', label='predicted')
plt.yticks(np.arange(0, 1.1, 0.1))
plt.xlabel('samples')
plt.ylabel('anomaly score')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# Measuring the effectiveness of classifier

# %%
fpr, tpr, thresholds = roc_curve(test_labels, anomaly_scores)

# %%
auc = roc_auc_score(test_labels, anomaly_scores)
print('Area under ROC curve: {}'.format(auc))
# Out:
# Area under ROC curve: 0.9861172161172163

# %%
plt.figure(figsize=(10,5))
plt.plot([0, 1], [0, 1], color = 'black', linestyle='--')
plt.plot(fpr, tpr, label='AUC={}'.format(auc))
plt.grid()
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
plt.title('ROC')
plt.show()

# %% [markdown]
# Identifying anomalies in test set

# %%
anomaly_combinations = [(anomaly_scores>i).astype(np.int32) for i in thresholds]
f1_scores = [f1_score(test_labels, i) for i in anomaly_combinations]

# %%
plt.figure(figsize=(10, 5))
plt.plot(thresholds, f1_scores)
plt.grid()
plt.xlabel('Thresholds')
plt.ylabel('F-1 Score')
plt.title('F-1 Score vs Thresholds')
plt.show()

# %%
max_f1_score = np.max(f1_scores)
best_threshold = thresholds[f1_scores.index(max_f1_score)]
print('best threshold = {}'.format(best_threshold))
# Out:
# best threshold = 0.025577589869499207

# %%
anomaly_indicator = (anomaly_scores>best_threshold).astype(np.int32)

# %%
confusion_matrix(test_labels, anomaly_indicator)
# Out:
# array([[   5,   10],
#        [   1, 1819]])

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(x=np.arange(0, len(anomaly_scores)), y= anomaly_scores, hue=['normal' if i==0 else 'anomaly' for i in anomaly_indicator],
                palette=['blue', 'red'], legend='full')
plt.axhline(y = best_threshold, linestyle='--', label='threshold')
plt.xlabel('samples')
plt.ylabel('anomaly score')
plt.legend()
plt.grid()
plt.show()

# %%
precision = precision_score(test_labels, anomaly_indicator)
recall = recall_score(test_labels, anomaly_indicator)
f1_sc = f1_score(test_labels, anomaly_indicator)
accuracy_sc = accuracy_score(test_labels, anomaly_indicator)

# %%
print('Model has the following classification metrics:\n precision = {}\n recall = {}\n f1_score = {}\n accuracy_score = {}'
      .format(precision, recall, f1_sc, accuracy_sc))
# Out:
# Model has the following classification metrics:
#  precision = 0.9945325314379442
#  recall = 0.9994505494505495
#  f1_score = 0.9969854754727322
#  accuracy_score = 0.9940054495912807
